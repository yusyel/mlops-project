# %%
from pymongo import MongoClient
import pandas as pd

# %%
client = MongoClient("mongodb://localhost:27017/")

# %%
def upload_target(filename):
    client = MongoClient("mongodb://localhost:27017/")
    collection = client.get_database("prediction_service").get_collection("data")
    with open(filename) as f_target:
        for line in f_target.readlines():
            row = line.split(",")
            collection.update_one({"id": row[0]}, {"$set": {"target": float(row[1])}})
    client.close()

upload_target("target.csv")

# %%
data = client.get_database("prediction_service").get_collection("data").find()
df = pd.DataFrame(list(data))
df.tail()
# Out:
#                           _id male  age education currentsmoker  cigsperday  \
# 549  62f8793a601a2daaace7b595    1   53       1.0             1        20.0
# 550  62f87b9e477d6b2db704f1d3    1   53       1.0             0         0.0
# 551  62f87ba0477d6b2db704f1d4    0   44       1.0             0         0.0
# 552  62f87ba3477d6b2db704f1d5    0   44       4.0             0         0.0
# 553  62f87ba5477d6b2db704f1d6    0   66       1.0             0         0.0
#
#     bpmeds prevalentstroke prevalenthyp diabetes  totchol  sysbp  diabp  \
# 549    0.0               0            0        0    188.0  138.0   89.0
# 550    0.0               0            0        0    220.0  127.0   76.0
# 551    0.0               0            0        0    195.0  118.0   86.0
# 552    0.0               0            0        0    205.0  109.0   73.0
# 553    0.0               1            1        0    278.0  187.0   88.0
#
#        bmi  heartrate  glucose  prediction  tenyearchd  \
# 549  18.23       60.0     75.0    0.218739         0.0
# 550  24.27       75.0     74.0    0.189975         0.0
# 551  23.09       70.0     75.0    0.092015         0.0
# 552  17.48       75.0     57.0    0.092015         0.0
# 553  40.52       90.0     84.0    0.223586         1.0
#
#                                        id
# 549  9578fd7d-819b-4f7b-80bb-840cc7ea025c
# 550  a2806726-8af3-46a4-bbc0-c98e276ce0b1
# 551  fd119ee3-39ca-4d91-b88a-f990d41d5953
# 552  347ec6c6-7ca2-4e18-80b0-c485014abc00
# 553  2b42898a-aa73-4f56-a62f-4e4264b21b23
